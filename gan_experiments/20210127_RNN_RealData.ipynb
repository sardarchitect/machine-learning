#         9967., 11344.,  9106., 10469., 10085.,  9612., 10328., 11483.,
#         7486.,  8641.,  9709.,  9423., 11342., 11274.,  9845., 11163.,
#         9532., 10754., 10953., 11922.,  8395.,  8888., 10110., 10493.,
#        12218., 11385., 11186., 11462., 10494., 11540., 11138., 12709.,
#         8557.,  9059., 10055., 10977., 11792., 11904., 10965., 10981.,
#        10828., 11817., 10470., 13310.,  8400.,  9062., 10722., 11107.,
#        11508., 12904., 11869., 11224., 12022., 11983., 11506., 14183.,
#         8648., 10321., 12107., 11420., 12238., 13681., 10950., 12700.,
#        12272., 11905., 13016., 14421.,  9043., 10452., 12481., 11491.,
#        13545., 14730., 11416., 13402., 11907., 12711., 13261., 14265.,
#         9564., 10415., 12683., 11919., 14138., 14583., 12640., 14257.,
#        12396., 13914., 14174., 15504., 10718.])

# %% [markdown]
# ## CREATE DATASETS

# %%
test_size = 12
train_set = y[:-test_size]
test_set = y[-test_size:]
test_set
# Out:
# array([10415., 12683., 11919., 14138., 14583., 12640., 14257., 12396.,
#        13914., 14174., 15504., 10718.])

# %% [markdown]
# ## NORMALIZE TRAINING SET BETWEEN -1 AND 1

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(-1,1))

# %%
scaler.fit(train_set.reshape(-1,1))
# Out:
# MinMaxScaler(copy=True, feature_range=(-1, 1))

# %%
train_norm = scaler.transform(train_set.reshape(-1,1))

# %% [markdown]
# ##

# %%
train_norm = torch.FloatTensor(train_norm).view(-1)
train_norm.shape
# Out:
# torch.Size([313])

# %% [markdown]
# ## DATALOADER

# %%
#AT LEAST 12 FOR EACH MONTH
window_size = 12

# %%
def input_data(seq, ws):
    out = []
    L = len(seq)
    for i in range(L-ws):
        window = seq[i:i+ws]
        label = seq[i+ws:i+ws+1]
        out.append((window, label)) #tuple
    return out

# %%
train_data = input_data(train_norm, window_size)

# %%
len(train_data)
# Out:
# 301

# %%
train_data[0]
# Out:
# (tensor([-0.9268, -0.9270, -0.8340, -0.7379, -0.7966, -0.7439, -0.7547, -0.8109,
#          -0.8128, -0.7901, -0.7933, -0.6743]), tensor([-1.]))

# %% [markdown]
# ## MODEL (LSTM)

# %%
class LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_size=100, out_size=1):
        super().__init__()
        self.hidden_size = hidden_size
        
        self.lstm = nn.LSTM(input_size, hidden_size)
        self.linear = nn.Linear(hidden_size, out_size)
        
        #(HIDDEN, CELL)
        self.hidden = (torch.zeros(1,1, hidden_size), torch.zeros(1,1, hidden_size))
        
    def forward(self, seq):
        lstm_out, self.hidden = self.lstm(seq.view(len(seq), 1, -1), self.hidden)
        pred = self.linear(lstm_out.view(len(seq), -1))
        
        #Out just last item
        return pred[-1]

# %% [markdown]
# ## CRITERION/ OPTIMIZER

# %%
torch.manual_seed(101)
model = LSTM()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
model
# Out:
# LSTM(
#   (lstm): LSTM(1, 100)
#   (linear): Linear(in_features=100, out_features=1, bias=True)
# )

# %%
numel = 0
for p in model.parameters():
    numel += (p.numel())
    print(p.numel())
print(numel)
# Out:
# 400
# 40000
# 400
# 400
# 100
# 1
# 41301

# %% [markdown]
# ## TRAIN AND TEST

# %%
epochs = 100
future = 40

import time 
start_time = time.time()

for i in range(epochs):
    
    for seq, y_train in train_data:
        optimizer.zero_grad()
        model.hidden = torch.zeros(1,1,model.hidden_size),torch.zeros(1,1,model.hidden_size)
        
        y_pred = model(seq)

        loss = criterion(y_pred, y_train)
        loss.backward()
        optimizer.step()
        
# Epoch 70 Loss: 1.0884616131079383e-05
# Epoch 71 Loss: 0.00010494267917238176
# Epoch 72 Loss: 0.00020110317564103752
# Epoch 73 Loss: 0.0005030538886785507
# Epoch 74 Loss: 0.0009722241084091365
# Epoch 75 Loss: 0.0004725400067400187
# Epoch 76 Loss: 0.0003622343938332051
# Epoch 77 Loss: 0.0001747752248775214
# Epoch 78 Loss: 0.0007094795000739396
# Epoch 79 Loss: 0.0005813314928673208
# Epoch 80 Loss: 0.000986728584393859
# Epoch 81 Loss: 0.001364932511933148
# Epoch 82 Loss: 0.0015522369649261236
# Epoch 83 Loss: 0.00039801953244023025
# Epoch 84 Loss: 0.000699073716532439
# Epoch 85 Loss: 0.0017407656414434314
# Epoch 86 Loss: 0.0004483309749048203
# Epoch 87 Loss: 0.0006013415986672044
# Epoch 88 Loss: 0.0006099726306274533
# Epoch 89 Loss: 0.0003789189795497805
# Epoch 90 Loss: 0.00040096690645441413
# Epoch 91 Loss: 0.0003898661816492677
# Epoch 92 Loss: 0.0002722437202464789
# Epoch 93 Loss: 0.00019703291764017195
# Epoch 94 Loss: 0.0007798975566402078
# Epoch 95 Loss: 0.0005938398535363376
# Epoch 96 Loss: 0.00029405782697722316
# Epoch 97 Loss: 0.0008473951020278037
# Epoch 98 Loss: 0.0007790413801558316
# Epoch 99 Loss: 0.0006697382195852697
# 4.215875605742137

# %%
future = 12
preds = train_norm[-window_size:].tolist()
model.eval()
for i in range(future):
    seq = torch.FloatTensor(preds[-window_size:])
    with torch.no_grad():
        model.hidden = torch.zeros(1,1,model.hidden_size),torch.zeros(1,1,model.hidden_size)
        preds.append(model(seq).item())

# %%
preds[window_size:]
# Out:
# [0.17993015050888062,
#  0.6447926163673401,
#  0.4197520911693573,
#  0.7942963242530823,
#  1.0360292196273804,
#  0.3529050946235657,
#  0.8711073994636536,
#  0.48376911878585815,
#  0.6796932220458984,
#  0.8363171219825745,
#  0.9388123154640198,
#  0.16515673696994781]

# %%
true_preds = scaler.inverse_transform(np.array(preds[window_size:]).reshape(-1,1))

# %%
true_preds
# Out:
# array([[ 9933.0014154 ],
#        [12652.21440944],
#        [11335.8398573 ],
#        [13526.73634872],
#        [14940.75292021],
#        [10944.818351  ],
#        [13976.04273316],
#        [11710.30746034],
#        [12856.36550236],
#        [13772.53700504],
#        [14372.08263931],
#        [ 9846.58433291]])

# %%
df['S4248SM144NCEN'][-12:]
# Out:
# DATE
# 2018-02-01    10415
# 2018-03-01    12683
# 2018-04-01    11919
# 2018-05-01    14138
# 2018-06-01    14583
# 2018-07-01    12640
# 2018-08-01    14257
# 2018-09-01    12396
# 2018-10-01    13914
# 2018-11-01    14174
# 2018-12-01    15504
# 2019-01-01    10718
# Name: S4248SM144NCEN, dtype: int64

# %%
x = np.arange('2018-02-01','2019-02-01', dtype='datetime64[M]')

# %%
x
# Out:
# array(['2018-02', '2018-03', '2018-04', '2018-05', '2018-06', '2018-07',
#        '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01'],
#       dtype='datetime64[M]')

# %%
df.index
# Out:
# DatetimeIndex(['1992-01-01', '1992-02-01', '1992-03-01', '1992-04-01',
#                '1992-05-01', '1992-06-01', '1992-07-01', '1992-08-01',
#                '1992-09-01', '1992-10-01',
#                ...
#                '2018-04-01', '2018-05-01', '2018-06-01', '2018-07-01',
#                '2018-08-01', '2018-09-01', '2018-10-01', '2018-11-01',
#                '2018-12-01', '2019-01-01'],
#               dtype='datetime64[ns]', name='DATE', length=325, freq=None)

# %%
plt.figure(figsize=(12,4))
plt.grid(True)
plt.plot(df['S4248SM144NCEN'])
plt.plot(x, true_preds)
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.grid(True)
plt.plot(df['S4248SM144NCEN']['2017-01-01':])
plt.plot(x, true_preds)
plt.show()

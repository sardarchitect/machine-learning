# %% [markdown]
# ## IMPORTS

# %%
import ics
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## UTIL

# %%
def event_to_dict(event):
    return{
        'name':event.name,
        'begin':event.begin.date().strftime('%Y-%m-%d'),
        'duration_mins': event.duration.seconds/60,
    }

# %% [markdown]
# ## ICS TO DF

# %%
file_path = 'D:/00_SARDARCHITECTLABS/local data/google-calendar-data/Projects_cadsvskbdp4b4a5njoeh4lp314@group.calendar.google.com.ics'

with open(file_path,'r') as f:
    icsFile = ics.Calendar(f.read())
    events = [event_to_dict(event) for event in icsFile.events]
#     print(events)

# %%
df = pd.DataFrame(events)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 993 entries, 0 to 992
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           993 non-null    object
#  1   begin          993 non-null    object
#  2   duration_mins  993 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 23.4+ KB
# None

# %%
df.head()
# Out:
#                   name       begin  duration_mins
# 0       Startup: Admin  2022-08-06           30.0
# 1  Help Kierra with ML  2022-04-19          105.0
# 2         Things to Do  2021-06-28           60.0
# 3  Startup: Operations  2022-09-13           30.0
# 4             ML: RNNs  2021-01-27          105.0

# %% [markdown]
# ## DATA CLEANING

# %%
# Convert Dates to Pandas DateTime
df['begin'] = pd.to_datetime(df['begin']).dt.normalize()

# %%
# Add column for duration_hrs
df['duration_hrs'] = df['duration_mins']/60

# %%
# Sort values by begin date and reset index
df = df.sort_values('begin', ascending=False)
df.reset_index(drop=True,inplace=True)

# %%
df.head(30)
# Out:
#                            name      begin  duration_mins  duration_hrs
# 0        Meeting: Rosa Taormina 2022-11-30           60.0          1.00
# 1                 UCSD: Unit 10 2022-11-06           30.0          0.50
# 2           Weekly Goals Review 2022-11-06          120.0          2.00
# 3                  UCSD: Review 2022-11-06           45.0          0.75
# 4                  UCSD: Review 2022-11-06          105.0          1.75
# 5                 UCSD: Unit 10 2022-11-05          120.0          2.00
# 7                 UCSD: Unit 10 2022-11-05          105.0          1.75
# 9                Meeting: Arnav 2022-11-05           30.0          0.50
# 10                UCSD: Unit 10 2022-11-04          120.0          2.00
# 12                 UCSD: Review 2022-11-02          150.0          2.50
# 13                 UCSD: Review 2022-11-02           45.0          0.75
# 15                 UCSD: Review 2022-11-02           45.0          0.75
# 18             Startup: Website 2022-10-31           60.0          1.00
# 19                           1: 2022-10-31          120.0          2.00
# 20          Startup: Operations 2022-10-30          135.0          2.25
# 21        Daily Journal Updates 2022-10-30           90.0          1.50
# 22          Startup: Operations 2022-10-30           30.0          0.50
# 23        Daily Journal Updates 2022-10-30          225.0          3.75
# 24                          17: 2022-10-30          120.0          2.00
# 25        Daily Journal Updates 2022-10-30           30.0          0.50
# 26                 UCSD: Review 2022-10-29           60.0          1.00
# 27                 UCSD: Review 2022-10-29           60.0          1.00
# 28                          11: 2022-10-29          120.0          2.00
# 29                 UCSD: Review 2022-10-29           60.0          1.00
# 30                       UCSD:  2022-10-28           90.0          1.50
# 31                 UCSD: Review 2022-10-28           60.0          1.00
# 32                 UCSD: Unit 8 2022-10-28           30.0          0.50
# 33                           8: 2022-10-28          120.0          2.00
# 34  Startup: Project Management 2022-10-28          120.0          2.00
# 35  Startup: Project Management 2022-10-28           60.0          1.00

# %%
# Split Job and Projects
activity_list = sorted(df["name"].unique().tolist())
activity_list
# Out:
# ['11:',
#  '17:',
#  '1:',
#  '7:',
#  '8:',
#  'AI Papers',
#  'AI Podcast',
#  'Architecture Book Reading',
#  'Architecture Floor Plan Generation',
#  'Artificial Intelligence: State of the Art - Lex Fridman',
#  'BHCC Course Registration',
#  'Blog Writing',
#  'Bootcamp Assesment',
#  'CS: Data Structures and Algorithms',
#  'Calendar Management',
#  'Call: Angel',
#  'Call: Arnav Dasaur',
#  'Call: Mike Mooney',
#  'Call: Robert Aung',
#  'Call: Rosa (SBA Mentor)',
#  'Call: Scott',
#  'Cleaning',
#  'Clubhouse with Brendan',
#  'Coding Practice',
#  'Cofounder Matching',
#  'Computational Portfolio',
#  'Computer Setup',
#  'Coures: Linear Algebra',
#  'Course: C++',
#  'Course: CSE599',
#  'Course: Data Structures',
#  'Course: Discrete Math',
#  'Course: EECS589',
#  'Course: EECS598',
#  'Course: EECS598_HW',
#  'Course: Graphics',
#  'Course: Math for ML',
#  'Course: Reinforcement Learning',
#  'Course: UCSD Prep',
#  'Course: Unreal Engine',
#  'Course: Unreal Engine 5',
#  'Coursera: Andrew Ng',
#  'Coursera: Deep Learning',
#  'Daily Journal Updates',
#  'Data compliance updates in the USA and Europe',
#  'Discrete Math',
#  'Draw',
#  'Drawing',
#  'E-Commerce: Inventory',
#  'EDA Work',
#  'Edge',
#  'Email Mark',
#  'Email draft: Matias del Campo',
#  'Email: Gabriel',
#  'Email: Mark',
#  'Email: Mark Farlow',
#  'Emails',
#  'Emails to Employers',
#  'Emails: Matias and Gabriel',
#  'Feature Engineering: What It Is & How to Leverage It in Your Data Science Career',
#  'Finances',
#  'Freelance: Jugnu Chacha House',
#  'Fscore: File Organization',
#  'Fscore: Marketing',
#  'Fscore: Product',
#  'Future Planning',
#  'GRE Prep',
#  'Grad Applications',
#  'Grad Apps',
#  'Grad School Apps',
#  'Grad School Research',
#  'Help Kierra with ML',
#  'India Shipment',
#  'India Stuff',
#  'Indian Stuff',
#  'Interview: Aerotek',
#  'Interview: Terrado Architects',
#  'Interview: Torrado Architects',
#  'Interview: Walker',
#  'Interview: Walker Consultants',
#  'Invitation: Arvinder/Sophia Chahal: MEC Career Coaching call @ Wed Sep 14, 2022 6pm - 6:30pm (EDT) (singh@arvinder.me)',
#  "Job Application'sApplications",
#  'Job Applications',
#  'Job Interview: CBT',
#  'Job Search',
#  'Kierra ML HW',
#  'Leetcode',
#  'Life Organizer - New System',
#  'Life Organizing',
#  'Life Planning',
#  'ML',
#  'ML Project',
#  'ML Project ',
#  'ML Research',
#  'ML Research: Matias del Campo Video',
#  'ML Tutorial',
#  'ML Tutorials',
#  'ML papers',
#  'ML tutorial',
#  'ML:  GANs',
#  'ML: Algorithms and Data Structures',
#  'ML: Architectural Dataset',
#  'ML: Architecture Dataset',
#  'ML: Climate Change',
#  'ML: Exercise (Migrate to Paperspace for PyTorch)',
#  'ML: Exercise (Pix2Pix) GANs',
#  'ML: GANs',
#  'ML: Grasshopper w/ Python',
#  'ML: Information Theory',
#  'ML: Linear Algebra',
#  'ML: Math Concepts',
#  'ML: Practice',
#  'ML: RNNs',
#  'ML: Resources Research',
#  'ML: Setup',
#  'ML: Theory on Pix2Pix',
#  'ML: Tutorial',
#  'ML: Tutorial GANs',
#  'ML: Tutorial Udemy',
#  'MSAIL',
#  'MSAIL Art',
#  'MSAIL: Art',
#  'Measuring',
#  'Meeting: Alexander Ivkin',
#  'Meeting: Arnav',
#  'Meeting: Career Coach',
#  'Meeting: Matias del Campo',
#  'Meeting: Natalia + Aylin',
#  'Meeting: Nikhil',
#  'Meeting: Raekwon',
#  'Meeting: Romil Sheth',
#  'Meeting: Rosa Taormina',
#  'Meeting: SCORE Mentor',
#  'Meeting: Virat Jaipur',
#  'Misc. Chores',
#  'Misc. Things to Do',
#  'NorthEastern Campus Tour',
#  'Organization: Computer',
#  'Organizing Schedule',
#  'Organizing: File Management',
#  'Organizing: Life Planning',
#  'Organizing: Planning',
#  'Organizing: Project Planning',
#  'Pickup Cargo',
#  'Planning: Life Planning',
#  'Portfolio',
#  'Portfolio ',
#  'Printer head cleaning ',
#  'Printer set up',
#  'Professional Networking Plan',
#  'Project Planning',
#  'Project: 3D Graphics',
#  'Project: Data Labeling Research',
#  'Project: East Tawas Planning',
#  'Project: Floor Plan Generator',
#  'Project: ML',
#  'Project: ML Readings',
#  'Project: Wooden Artifacts',
#  'Python: Practice',
#  'Q1 2021 Goals',
#  'QnA with Lex Fridman',
#  'Read: AI',
#  'Read: Data Science',
#  'Read: Data Science MIT',
#  'Read: Intro to AI',
#  'Read: Intro to AI ',
#  'Read: Raspberry Pi ',
#  'Read: Research Paper',
#  "Read: So Good They Can't Ignore You",
#  'Research Papers',
#  'Research ayurvedic products',
#  'Research: AI + Architecture',
#  'Research: CBT Architects',
#  'Research: CS Programs',
#  'Savvy Crafts',
#  'Savvy Crafts Shipment',
#  'Score Startup Roadmap',
#  'Scott Meeting',
#  'Scott Project',
#  'Sell Indian Artifacts',
#  'Shopify',
#  'Startup',
#  'Startup Ideas (AI papers)',
#  'Startup Thinking',
#  'Startup Week (Look into attending an event)',
#  'Startup:',
#  'Startup: ',
#  'Startup: Admin',
#  'Startup: Business Plan',
#  'Startup: Employee Interview',
#  'Startup: File Organizing',
#  'Startup: Goals and Updates',
#  'Startup: Hiring',
#  'Startup: Legal',
#  'Startup: Logo',
#  'Startup: Marketing',
#  'Startup: NAS Purchase',
#  'Startup: Networking',
#  'Startup: Networking Email',
#  'Startup: Operations',
#  'Startup: Planning',
#  'Startup: Project Management',
#  'Startup: Registration',
#  'Startup: Research',
#  'Startup: RnD',
#  'Startup: Roadmap',
#  'Startup: Startup Week Webinars',
#  'Startup: Things to Do',
#  'Startup: Todo',
#  'Startup: Website',
#  'Startup: Workflow',
#  'Studio conversation - Mon., May 3',
#  'Talk: AI + Architecture',
#  'Things to Do',
#  'Things to do',
#  'To do',
#  'Todo',
#  'Trello Set up',
#  'Trello Setup',
#  'Tutorial: Grasshopper',
#  'UCSD:',
#  'UCSD: ',
#  'UCSD: Advisor Meeting',
#  'UCSD: Capstone',
#  'UCSD: Career Coach',
#  'UCSD: File Organizing',
#  'UCSD: Mentor',
#  'UCSD: Mentor Call',
#  'UCSD: Mini Projects',
#  'UCSD: Notes',
#  'UCSD: Prep',
#  'UCSD: Prepwork',
#  'UCSD: Review',
#  'UCSD: Skills Assessment',
#  'UCSD: Unit ',
#  'UCSD: Unit 10',
#  'UCSD: Unit 2',
#  'UCSD: Unit 3',
#  'UCSD: Unit 4',
#  'UCSD: Unit 5',
#  'UCSD: Unit 6',
#  'UCSD: Unit 8',
#  'Udemy: React Expo',
#  'Unreal Engine',
#  'Weekly Goals Review',
#  'Work',
#  'Work: Walker Consultants',
#  'Writing: Project Framework',
#  'co.de.D Innovator Spotlight: Computational Design']

# %%
# Remove Edge, EDA Work, Work, Work: Walker Consultants
indexWork = df[(df['name'] == 'Work: Walker Consultants') | (df['name'] == 'Work') | (df['name'] == 'EDA Work')| (df['name'] == 'Edge')].index
df.drop(indexWork, inplace=True)
len(df)
# Out:
# 916

# %% [markdown]
# ## Hours worked (Daily, Weekly, Monthly)

# %%
daterange = pd.DataFrame(pd.date_range('2020-01-01','2022-12-31'))
daterange.rename(columns={0:'date'}, inplace=True)
daterange
# Out:
#            date
# 0    2020-01-01
# 1    2020-01-02
# 2    2020-01-03
# 3    2020-01-04
# 4    2020-01-05
# ...         ...
# 1091 2022-12-27
# 1092 2022-12-28
# 1093 2022-12-29
# 1094 2022-12-30
# 1095 2022-12-31
#
# [1096 rows x 1 columns]

# %%
data_2022 = df[df['begin'] >= "2020-01-01"]
data_2022.head()

# %%
df2022 = daterange.merge(data_2022, left_on='date', right_on='begin', how='left')

# %%
df2022

# %%
df2022['date'] = pd.to_datetime(df2022['date']) - pd.to_timedelta(7, unit='d')
df2022 = df2022.groupby([pd.Grouper(key="date", freq='W-MON')])['duration_hrs'].sum().reset_index().sort_values('date')
df2022.head()

# %%
df2022['duration_hrs'].plot()

# %%
import torch
import torch.nn as nn
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import os
import time

# %%
device = torch.device('cpu')
if (torch.cuda.is_available()):
    device = torch.device('cuda')

# %% [markdown]
# ## HYPERPARAMS

# %%
dataroot = '../storage/data/AS_storage/'
workers = 4
batch_size = 32
image_size = 784
label_dim=10
nc = 1
nz = 100

num_epochs = 50
lr = 0.0002
momentum = 0.5
dampening = 0

k=1

# %% [markdown]
# ## DATA

# %%
transforms = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
])

train_ds = torchvision.datasets.FashionMNIST(dataroot, train=True, download=True, transform=transforms)
train_dl = torch.utils.data.DataLoader(train_ds, batch_size, shuffle=True, num_workers=workers)
print('Length of dataset:',len(train_ds))
# Out:
# Length of dataset: 60000

# %% [markdown]
# 0: T-shirt/top
# 1: Trouser
# 2: Pullover
# 3: Dress
# 4: Coat
# 5: Sandal
# 6: Shirt
# 7: Sneaker
# 8: Bag
# 9: Ankle boot

# %%
for images, labels in train_dl:
    print('Images shape:',images.shape)
    plt.imshow(torchvision.utils.make_grid(images, nrow=8).permute(1,2,0))
    print('Labels:',labels)
    break
# Out:
# Images shape: torch.Size([32, 1, 28, 28])
# Labels: tensor([6, 0, 5, 9, 5, 6, 2, 8, 4, 8, 0, 1, 4, 4, 6, 8, 1, 9, 5, 7, 5, 0, 9, 0,
#         3, 2, 9, 0, 1, 5, 4, 0])

# %% [markdown]
# ## MODELS

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        
        self.label_emb = nn.Embedding(10,10)
        
        self.fc1 = nn.Sequential(
            nn.Linear(nz+label_dim , 256),
            nn.LeakyReLU(0.2),
        )
        self.fc2 = nn.Sequential(
            nn.Linear(256 , 512),
            nn.LeakyReLU(0.2),
        )
        self.fc3 = nn.Sequential(
            nn.Linear(512 , 1024),
            nn.LeakyReLU(0.2),
        )
        self.fc4 = nn.Sequential(
            nn.Linear(1024 , 784),
            nn.Tanh()
        )
        
    def forward(self, images, labels):
        #RECIEVES BATCH OF SIZE (batch_size, nz)
        images = images.view(images.size(0), -1)
        labels = self.label_emb(labels)
        out = torch.cat((images, labels), dim=1)
        out = self.fc1(out)
        out = self.fc2(out)
        out = self.fc3(out)
        out = self.fc4(out)
        return out

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.label_emb = nn.Embedding(10,10)

        
        self.fc1 = nn.Sequential(
            nn.Linear(784+label_dim, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        self.fc2 = nn.Sequential(
            nn.Linear(1024 , 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        self.fc3 = nn.Sequential(
            nn.Linear(512 , 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        self.fc4 = nn.Sequential(
            nn.Linear(256 , 1),
            nn.Sigmoid()
        )
        
    def forward(self, images, labels):
        #RECIEVES BATCH OF SIZE (batch_size, 784) or (batch_size, 1, 28, 28)
        images = images.view(images.size(0), -1)
        labels = self.label_emb(labels)
        out = torch.cat((images, labels), dim=1)
        out = self.fc1(out)
        out = self.fc2(out)
        out = self.fc3(out)
        out = self.fc4(out)
        return out

# %%
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# %% [markdown]
# ## LOSS FUNCTIONS

# %%
opt_g = torch.optim.Adam(generator.parameters(), lr)
opt_d = torch.optim.Adam(discriminator.parameters(), lr)

criterion = nn.BCELoss()

# %% [markdown]
# ## PRE-TRAIN FUNCTIONS

# %%
real_labels = torch.ones(batch_size,1).to(device)
fake_labels = torch.zeros(batch_size,1).to(device)

# %%
fixed_noise = torch.randn(10, nz).to(device)
fixed_conditions = torch.LongTensor(np.arange(0,10)).to(device)

# %% [markdown]
# ## PRE-TRAIN TEST

# %%
# sample = generator(fixed_noise, fixed_conditions).detach()
# print("Generated Samples:", sample.shape)

# sample_output = discriminator(sample, fixed_conditions).detach()
# print("Sample Outputs:", sample_output.shape)

# %% [markdown]
# ## TRAIN

# %%
start_time = time.time()

loss_d = []
loss_g = []

for epoch in range(num_epochs):
    loss_d_ = 0.0
    loss_g_ = 0.0
    for i, (images, labels) in enumerate(train_dl):
        #DISCRIMINATOR
        opt_d.zero_grad()
        
        real_conditions = labels.to(device)        
        real_images = images.to(device)
        fake_conditions = torch.randint(0,10,(batch_size,)).to(device)
        fake_images = generator(torch.randn(batch_size, nz).to(device), fake_conditions).detach()
        
        real_outputs = discriminator(real_images, real_conditions) 
        fake_outputs = discriminator(fake_images, fake_conditions) 
        
        real_loss = criterion(real_outputs, real_labels)
        fake_loss = criterion(fake_outputs, fake_labels)
        real_loss.backward()
        fake_loss.backward()
        
        opt_d.step()
        
        loss_d_ += real_loss + fake_loss
        
        #GENERATOR
        opt_g.zero_grad()
        
        fake_conditions = torch.randint(0,10,(batch_size,)).to(device)
        output = discriminator(generator(torch.randn(batch_size, nz).to(device), fake_conditions), fake_conditions)
        
        loss = criterion(output, real_labels)
        loss.backward()
        
        opt_g.step()
        
        loss_g_ += loss
    
    epoch_loss_g = loss_g_/i
    epoch_loss_d = loss_d_/i
    loss_g.append(epoch_loss_g)
    loss_d.append(epoch_loss_d)
    print(f'{epoch}/{num_epochs} | Generator_Loss: {epoch_loss_g:.8f} | Discriminator_Loss: {epoch_loss_d:.8f} | Time: {time.time() - start_time:.0f} seconds')
    
    if epoch%10==0:
        sample = generator(fixed_noise, fixed_conditions).detach()
        grid = torchvision.utils.make_grid(sample.view(-1, 1, 28, 28), nrow=5, pad_value=1, normalize=False)   
        torchvision.utils.save_image(grid.detach().cpu(), os.path.join('visuals', 'FashionMNIST_cGAN_{}.jpg'.format(str(epoch).zfill(3))))    
    
print(f'\nTOTAL DURATION: {time.time() - start_time:.0f} seconds')
sample = generator(fixed_noise, fixed_conditions).detach()
grid = torchvision.utils.make_grid(sample.view(-1, 1, 28, 28), nrow=5, pad_value=1, normalize=False)   
torchvision.utils.save_image(grid.detach().cpu(), os.path.join('visuals', 'FashionMNIST_cGAN_50.jpg'))
# Out:
# 0/50 | Generator_Loss: 1.55190969 | Discriminator_Loss: 1.08378148 | Time: 32 seconds
# 1/50 | Generator_Loss: 1.49323690 | Discriminator_Loss: 1.04251111 | Time: 65 seconds
# 2/50 | Generator_Loss: 1.12169898 | Discriminator_Loss: 1.13725841 | Time: 97 seconds
# 3/50 | Generator_Loss: 1.04888153 | Discriminator_Loss: 1.18376887 | Time: 129 seconds
# 4/50 | Generator_Loss: 1.09445965 | Discriminator_Loss: 1.17066956 | Time: 161 seconds
# 5/50 | Generator_Loss: 1.09742022 | Discriminator_Loss: 1.16182899 | Time: 193 seconds
# 6/50 | Generator_Loss: 1.07326376 | Discriminator_Loss: 1.19137192 | Time: 225 seconds
# 7/50 | Generator_Loss: 1.08383131 | Discriminator_Loss: 1.17225969 | Time: 258 seconds
# 8/50 | Generator_Loss: 1.12961471 | Discriminator_Loss: 1.15747344 | Time: 290 seconds
# 9/50 | Generator_Loss: 1.12597239 | Discriminator_Loss: 1.13897860 | Time: 323 seconds
# 10/50 | Generator_Loss: 1.13951921 | Discriminator_Loss: 1.11955321 | Time: 356 seconds
# 11/50 | Generator_Loss: 1.12749517 | Discriminator_Loss: 1.13702905 | Time: 389 seconds
# 12/50 | Generator_Loss: 1.11261523 | Discriminator_Loss: 1.16010725 | Time: 421 seconds
# 13/50 | Generator_Loss: 1.09642768 | Discriminator_Loss: 1.14898360 | Time: 453 seconds
# 14/50 | Generator_Loss: 1.14239919 | Discriminator_Loss: 1.12771416 | Time: 485 seconds
# 15/50 | Generator_Loss: 1.12585354 | Discriminator_Loss: 1.14966750 | Time: 518 seconds
# 16/50 | Generator_Loss: 1.15360403 | Discriminator_Loss: 1.13204694 | Time: 550 seconds
# 17/50 | Generator_Loss: 1.16503477 | Discriminator_Loss: 1.11790729 | Time: 583 seconds
# 18/50 | Generator_Loss: 1.15269709 | Discriminator_Loss: 1.13581228 | Time: 615 seconds
# 19/50 | Generator_Loss: 1.13590956 | Discriminator_Loss: 1.13325071 | Time: 648 seconds
# 20/50 | Generator_Loss: 1.15223145 | Discriminator_Loss: 1.13126838 | Time: 680 seconds
# 21/50 | Generator_Loss: 1.15571046 | Discriminator_Loss: 1.13037539 | Time: 713 seconds
# 22/50 | Generator_Loss: 1.16729414 | Discriminator_Loss: 1.11988127 | Time: 746 seconds
# 23/50 | Generator_Loss: 1.17263675 | Discriminator_Loss: 1.11693192 | Time: 778 seconds
# 24/50 | Generator_Loss: 1.19353700 | Discriminator_Loss: 1.09687769 | Time: 810 seconds
# 25/50 | Generator_Loss: 1.12645864 | Discriminator_Loss: 1.14613748 | Time: 843 seconds
# 26/50 | Generator_Loss: 1.12182283 | Discriminator_Loss: 1.13346040 | Time: 875 seconds
# 27/50 | Generator_Loss: 1.14536393 | Discriminator_Loss: 1.13977098 | Time: 908 seconds
# 28/50 | Generator_Loss: 1.21290815 | Discriminator_Loss: 1.08079624 | Time: 940 seconds
# 29/50 | Generator_Loss: 1.17770600 | Discriminator_Loss: 1.11133492 | Time: 973 seconds
# 30/50 | Generator_Loss: 1.12332070 | Discriminator_Loss: 1.14232302 | Time: 1006 seconds
# 31/50 | Generator_Loss: 1.13698256 | Discriminator_Loss: 1.13219142 | Time: 1038 seconds
# 32/50 | Generator_Loss: 1.14105582 | Discriminator_Loss: 1.13167906 | Time: 1071 seconds
# 33/50 | Generator_Loss: 1.20371997 | Discriminator_Loss: 1.09133780 | Time: 1104 seconds
# 34/50 | Generator_Loss: 1.14618456 | Discriminator_Loss: 1.12944627 | Time: 1136 seconds
# 35/50 | Generator_Loss: 1.13705909 | Discriminator_Loss: 1.13144207 | Time: 1169 seconds
# 36/50 | Generator_Loss: 1.14873970 | Discriminator_Loss: 1.13228810 | Time: 1202 seconds
# 37/50 | Generator_Loss: 1.15881956 | Discriminator_Loss: 1.12710512 | Time: 1235 seconds
# 38/50 | Generator_Loss: 1.18841279 | Discriminator_Loss: 1.10646999 | Time: 1268 seconds
# 39/50 | Generator_Loss: 1.23176336 | Discriminator_Loss: 1.09296083 | Time: 1300 seconds
# 40/50 | Generator_Loss: 1.17776012 | Discriminator_Loss: 1.11314964 | Time: 1333 seconds
# 41/50 | Generator_Loss: 1.16513431 | Discriminator_Loss: 1.11012959 | Time: 1366 seconds
# 42/50 | Generator_Loss: 1.18846369 | Discriminator_Loss: 1.10448992 | Time: 1399 seconds
# 43/50 | Generator_Loss: 1.18153822 | Discriminator_Loss: 1.10217965 | Time: 1432 seconds
# 44/50 | Generator_Loss: 1.19427419 | Discriminator_Loss: 1.10192680 | Time: 1464 seconds
# 45/50 | Generator_Loss: 1.16842389 | Discriminator_Loss: 1.12463033 | Time: 1497 seconds
# 46/50 | Generator_Loss: 1.20263720 | Discriminator_Loss: 1.09677100 | Time: 1530 seconds
# 47/50 | Generator_Loss: 1.17352796 | Discriminator_Loss: 1.11995041 | Time: 1563 seconds
# 48/50 | Generator_Loss: 1.20555234 | Discriminator_Loss: 1.09794700 | Time: 1596 seconds
# 49/50 | Generator_Loss: 1.19703019 | Discriminator_Loss: 1.10365736 | Time: 1629 seconds
#
# TOTAL DURATION: 1629 seconds

# %%
sample = generator(fixed_noise, fixed_conditions).detach()
grid = torchvision.utils.make_grid(sample.view(-1, 1, 28, 28), nrow=5, pad_value=1, normalize=False)   
plt.imshow(grid.detach().cpu().permute(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## EVALUATION

# %%
plt.figure()

plt.plot(loss_d, label='LOSS D')
plt.plot(loss_g, label='LOSS G')
plt.legend()
plt.show()

# %%
def generateItem(label):
    noise = torch.randn(1,nz)
    label = torch.LongTensor(label)
    img = generator(noise, label)
    plt.imshow(img.detach().cpu().permute(1,2,0))

# %%
generateItem(1)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-62-51d59d77646b> in <module>
# ----> 1 generateItem(1)
#
# <ipython-input-61-287ce0e97aea> in generateItem(label)
#       2     noise = torch.randn(1,nz)
#       3     label = torch.LongTensor(label)
# ----> 4     img = generator(noise, label)
#       5     plt.imshow(img.detach().cpu().permute(1,2,0))
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# <ipython-input-6-ce5b0d4f05be> in forward(self, images, labels)
#      25         #RECIEVES BATCH OF SIZE (batch_size, nz)
#      26         images = images.view(images.size(0), -1)
# ---> 27         labels = self.label_emb(labels)
#      28         out = torch.cat((images, labels), dim=1)
#      29         out = self.fc1(out)
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torch/nn/modules/sparse.py in forward(self, input)
#     122
#     123     def forward(self, input: Tensor) -> Tensor:
# --> 124         return F.embedding(
#     125             input, self.weight, self.padding_idx, self.max_norm,
#     126             self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    1850         # remove once script supports set_grad_enabled
#    1851         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 1852     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    1853
#    1854
#
# RuntimeError: Input, output and indices must be on the current device

# %% [markdown]
# ## SAVING

# %%
torch.save(generator.state_dict(), './fashion_mnist_cgan_generator.pt')
torch.save(discriminator.state_dict(), './fashion_mnist_cgan_discriminator.pt')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-63-63820f908f48> in <module>
# ----> 1 torch.save(generator.state_dict(), './fashion_mnist_cgan_generator.pt')
#       2 torch.save(discriminator.state_dict(), './fashion_mnist_cgan_discriminator.pt')
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     370         if _use_new_zipfile_serialization:
#     371             with _open_zipfile_writer(opened_file) as opened_zipfile:
# --> 372                 _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     373                 return
#     374         _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     489             # Copy to a buffer, then serialize that
#     490             buf = io.BytesIO()
# --> 491             storage._write_file(buf, _should_read_directly(buf), False)
#     492             buf_value = buf.getvalue()
#     493             zip_file.write_record(name, buf_value, len(buf_value))
#
# RuntimeError: cuda runtime error (710) : device-side assert triggered at /pytorch/torch/csrc/generic/serialization.cpp:31

# %%
import torch
import torch.nn as nn
import torchvision
import numpy as np
import matplotlib.pyplot as plt
import os
import time

# %%
device = torch.device('cpu')
if (torch.cuda.is_available()):
    device = torch.device('cuda')

# %% [markdown]
# ## HYPERPARAMS

# %%
dataroot = '../storage/data/AS_storage/'
workers = 4
batch_size = 32
image_size = 784
nc = 1
nz = 100

num_epochs = 50
lr = 0.0002
momentum = 0.5
dampening = 0

k=1

# %% [markdown]
# ## DATA

# %%
transforms = torchvision.transforms.Compose([
    torchvision.transforms.ToTensor(),
])

train_ds = torchvision.datasets.FashionMNIST(dataroot, train=True, download=True, transform=transforms)
train_dl = torch.utils.data.DataLoader(train_ds, batch_size, shuffle=True, num_workers=workers)
print('Length of dataset:',len(train_ds))
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ../storage/data/AS_storage/FashionMNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0), HTML(value=''…
# Extracting ../storage/data/AS_storage/FashionMNIST/raw/train-images-idx3-ubyte.gz to ../storage/data/AS_storage/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ../storage/data/AS_storage/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0), HTML(value=''…
# Extracting ../storage/data/AS_storage/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ../storage/data/AS_storage/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ../storage/data/AS_storage/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0), HTML(value=''…
# Extracting ../storage/data/AS_storage/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ../storage/data/AS_storage/FashionMNIST/raw
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ../storage/data/AS_storage/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', layout=Layout(width='20px'), max=1.0), HTML(value=''…
# Extracting ../storage/data/AS_storage/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ../storage/data/AS_storage/FashionMNIST/raw
# Processing...
# /opt/conda/envs/fastai/lib/python3.8/site-packages/torchvision/datasets/mnist.py:480: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:141.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)
# Done!
# Length of dataset: 60000

# %% [markdown]
# 0: T-shirt/top
# 1: Trouser
# 2: Pullover
# 3: Dress
# 4: Coat
# 5: Sandal
# 6: Shirt
# 7: Sneaker
# 8: Bag
# 9: Ankle boot

# %%
for images, labels in train_dl:
    print('Images shape:',images.shape)
    plt.imshow(torchvision.utils.make_grid(images, nrow=8).permute(1,2,0))
    print('Labels:',labels)
    break
# Out:
# Images shape: torch.Size([32, 1, 28, 28])
# Labels: tensor([1, 5, 6, 1, 2, 7, 9, 3, 0, 9, 7, 1, 3, 9, 1, 9, 3, 0, 2, 7, 9, 5, 0, 8,
#         6, 1, 1, 4, 3, 9, 9, 5])

# %% [markdown]
# ## MODELS

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        
        self.fc1 = nn.Sequential(
            nn.Linear(nz , 256),
            nn.LeakyReLU(0.2),
        )
        self.fc2 = nn.Sequential(
            nn.Linear(256 , 512),
            nn.LeakyReLU(0.2),
        )
        self.fc3 = nn.Sequential(
            nn.Linear(512 , 1024),
            nn.LeakyReLU(0.2),
        )
        self.fc4 = nn.Sequential(
            nn.Linear(1024 , 784),
            nn.Tanh()
        )
        
    def forward(self, batch):
        #RECIEVES BATCH OF SIZE (batch_size, nz)
        batch = batch.view(batch.size(0), -1)
        out = self.fc1(batch)
        out = self.fc2(out)
        out = self.fc3(out)
        out = self.fc4(out)
        return out

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.fc1 = nn.Sequential(
            nn.Linear(784 , 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        self.fc2 = nn.Sequential(
            nn.Linear(1024 , 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        self.fc3 = nn.Sequential(
            nn.Linear(512 , 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        self.fc4 = nn.Sequential(
            nn.Linear(256 , 1),
            nn.Sigmoid()
        )
        
    def forward(self, batch):
        #RECIEVES BATCH OF SIZE (batch_size, 784) or (batch_size, 1, 28, 28)
        batch = batch.view(batch.size(0), -1)
        out = self.fc1(batch)
        out = self.fc2(out)
        out = self.fc3(out)
        out = self.fc4(out)
        return out

# %%
generator = Generator().to(device)
discriminator = Discriminator().to(device)

# %% [markdown]
# ## LOSS FUNCTIONS

# %%
opt_g = torch.optim.Adam(generator.parameters(), lr)
opt_d = torch.optim.Adam(discriminator.parameters(), lr)

criterion = nn.BCELoss()

# %% [markdown]
# ## PRE-TRAIN FUNCTIONS

# %%
real_labels = torch.ones(batch_size,1).to(device)
fake_labels = torch.zeros(batch_size,1).to(device)

# %%
fixed_noise = torch.randn(batch_size, nz).to(device)

# %% [markdown]
# ## PRE-TRAIN TEST

# %%
sample = generator(fixed_noise).detach()
print("Generated Samples:", sample.shape)

sample_output = discriminator(sample).detach()
print("Sample Outputs:", sample_output.shape)
# Out:
# Generated Samples: torch.Size([32, 784])
# Sample Outputs: torch.Size([32, 1])

# %% [markdown]
# ## TRAIN

# %%
start_time = time.time()

loss_d = []
loss_g = []

for epoch in range(num_epochs):
    loss_d_ = 0.0
    loss_g_ = 0.0
    for i, (images, _) in enumerate(train_dl):
        #DISCRIMINATOR
        opt_d.zero_grad()
        
        real_images = images.to(device)
        fake_images = generator(torch.randn(batch_size, nz).to(device)).detach()
        
        real_outputs = discriminator(real_images) 
        fake_outputs = discriminator(fake_images) 
        
        real_loss = criterion(real_outputs, real_labels)
        fake_loss = criterion(fake_outputs, fake_labels)
        real_loss.backward()
        fake_loss.backward()
        
        opt_d.step()
        
        loss_d_ += real_loss + fake_loss
        
        #GENERATOR
        opt_g.zero_grad()
        
        output = discriminator(generator(torch.randn(batch_size, nz).to(device)))
        
        loss = criterion(output, real_labels)
        loss.backward()
        
        opt_g.step()
        
        loss_g_ += loss
    
    epoch_loss_g = loss_g_/i
    epoch_loss_d = loss_d_/i
    loss_g.append(epoch_loss_g)
    loss_d.append(epoch_loss_d)
    print(f'{epoch}/{num_epochs} | Generator_Loss: {epoch_loss_g:.8f} | Discriminator_Loss: {epoch_loss_d:.8f} | Time Elapsed: {time.time() - start_time:.0f} seconds')
    
    if epoch%10==0:
        sample = generator(fixed_noise).detach()
        grid = torchvision.utils.make_grid(sample.view(-1, 1, 28, 28), nrow=8, pad_value=1, normalize=False)   
        torchvision.utils.save_image(grid.detach().cpu(), os.path.join('visuals', 'FashionMNIST_VANILLA_GAN_{}.jpg'.format(str(epoch).zfill(3))))    
    
print(f'\nTOTAL DURATION: {time.time() - start_time:.0f} seconds')
sample = generator(fixed_noise).detach()
grid = torchvision.utils.make_grid(sample.view(-1, 1, 28, 28), nrow=8, pad_value=1, normalize=False)   
torchvision.utils.save_image(grid.detach().cpu(), os.path.join('visuals', 'FashionMNIST_VANILLA_GAN_50.jpg'))
# Out:
# 0/50 | Generator_Loss: 1.25788069 | Discriminator_Loss: 1.16339052 | Time Elapsed: 20 seconds
# 1/50 | Generator_Loss: 1.21234274 | Discriminator_Loss: 1.08271182 | Time Elapsed: 40 seconds
# 2/50 | Generator_Loss: 1.41595745 | Discriminator_Loss: 0.95831674 | Time Elapsed: 60 seconds
# 3/50 | Generator_Loss: 1.32675791 | Discriminator_Loss: 0.99910009 | Time Elapsed: 79 seconds
# 29/50 | Generator_Loss: 1.18347371 | Discriminator_Loss: 1.04239893 | Time Elapsed: 605 seconds
# 30/50 | Generator_Loss: 1.19499397 | Discriminator_Loss: 1.03919613 | Time Elapsed: 625 seconds
# 31/50 | Generator_Loss: 1.20885241 | Discriminator_Loss: 1.01217854 | Time Elapsed: 646 seconds
# 32/50 | Generator_Loss: 1.20696259 | Discriminator_Loss: 1.01510131 | Time Elapsed: 666 seconds
# 33/50 | Generator_Loss: 1.22720516 | Discriminator_Loss: 1.01225984 | Time Elapsed: 686 seconds
# 34/50 | Generator_Loss: 1.21526921 | Discriminator_Loss: 1.00451899 | Time Elapsed: 707 seconds
# 35/50 | Generator_Loss: 1.22581160 | Discriminator_Loss: 0.99730855 | Time Elapsed: 727 seconds
# 36/50 | Generator_Loss: 1.23741829 | Discriminator_Loss: 1.00176036 | Time Elapsed: 748 seconds
# 37/50 | Generator_Loss: 1.20718908 | Discriminator_Loss: 1.00688231 | Time Elapsed: 768 seconds
# 38/50 | Generator_Loss: 1.23006201 | Discriminator_Loss: 1.00663638 | Time Elapsed: 790 seconds
# 39/50 | Generator_Loss: 1.22523296 | Discriminator_Loss: 1.00479782 | Time Elapsed: 810 seconds
# 40/50 | Generator_Loss: 1.25300634 | Discriminator_Loss: 0.99257696 | Time Elapsed: 831 seconds
# 41/50 | Generator_Loss: 1.23494327 | Discriminator_Loss: 0.98645449 | Time Elapsed: 851 seconds
# 42/50 | Generator_Loss: 1.24077272 | Discriminator_Loss: 0.99110889 | Time Elapsed: 872 seconds
# 43/50 | Generator_Loss: 1.24243724 | Discriminator_Loss: 0.97983700 | Time Elapsed: 892 seconds
# 44/50 | Generator_Loss: 1.24193406 | Discriminator_Loss: 0.97951984 | Time Elapsed: 912 seconds
# 45/50 | Generator_Loss: 1.25236738 | Discriminator_Loss: 0.99019837 | Time Elapsed: 933 seconds
# 46/50 | Generator_Loss: 1.24791527 | Discriminator_Loss: 0.97481263 | Time Elapsed: 953 seconds
# 47/50 | Generator_Loss: 1.23283947 | Discriminator_Loss: 0.98781621 | Time Elapsed: 973 seconds
# 48/50 | Generator_Loss: 1.25890601 | Discriminator_Loss: 0.96811688 | Time Elapsed: 994 seconds
# 49/50 | Generator_Loss: 1.26728857 | Discriminator_Loss: 0.97179151 | Time Elapsed: 1014 seconds
#
# TOTAL DURATION: 1014 seconds

# %% [markdown]
# ## EVALUATION

# %%
plt.figure()

plt.plot(loss_d, label='LOSS D')
plt.plot(loss_g, label='LOSS G')
plt.legend()
plt.show()

# %% [markdown]
# ## SAVING

# %%
torch.save(generator.state_dict(), './fashion_mnist_vanilla_gan_generator.pt')
torch.save(discriminator.state_dict(), './fashion_mnist_vanilla_gan_discriminator.pt')
